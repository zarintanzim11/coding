# %% [markdown]
# <a href="https://colab.research.google.com/github/zarintanzim11/coding/blob/main/startc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Starting my journey with skill morph")
# Out:
# Starting my journey with skill morph
