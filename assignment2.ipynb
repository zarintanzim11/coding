# %% [markdown]
# <a href="https://colab.research.google.com/github/zarintanzim11/coding/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## H1: Write a program to perform the subtraction, multipllication and division
print("Enter First Number: ")
numOne = int(input())
print("Enter Second Number: ")
numTwo = int(input())
res = numOne+numTwo
print("\nAddition Result = ", res)
res = numOne-numTwo
print("Subtraction Result = ", res)
res = numOne*numTwo
print("Multiplication Result = ", res)
res = numOne/numTwo
print("Division Result = ", res)
# Out:
# Enter First Number:
# 12
# Enter Second Number:
# 6
#
# Addition Result =  18
# Subtraction Result =  6
# Multiplication Result =  72
# Division Result =  2.0

# %%
## H2: Write a program to declare variables for id, name, batch, and hometown, and assign values, and finally print.
# Variable declarations and assignments
student_id = 101 # Integer
name = "Alice Johnson" # String
batch = "CS-2026" # String
hometown = "Chattogram" # String
# Printing the values
print("Student Details:")
print("ID : ",student_id)
print("Name : ", name)
print("Batch :", batch)
print("Hometown : ", hometown)
# Out:
# Student Details:
# ID :  101
# Name :  Alice Johnson
# Batch : CS-2026
# Hometown :  Chattogram

# %%
## H3: Write a program to change values of an integer variable
# Initial value
x = int(input())
print(x) # Output: 5



# Incrementing the value
x += 3
print("\n After incrementing:",x) # Output: 13

# Decrementing the value
x -= 2
print("\n After decrementing:", x) # Output: 11
# Reassigning to a new value
x = int(input())
print("\n After reassigning new value: ",x) # Output: 10
# Out:
# 3
# 3
#
#  After incrementing: 6
#
#  After decrementing: 4
# 7
#
#  After reassigning new value:  7

# %%
##H4: Write a program to take two string numbers and convert them to integers using explicit type conversion.
#s = "42"
s= input("Enter input :")
num = int(s)
print("\n Printing num as integer value: "num)
# Out:
# Enter input :34
# 34

# %%
## H5: Write a program to calculate and print the average of the three numbers. Round the result to two decimal places.
# Initializing three numbers
num1 = int(input("Enter First number:"))
num2= int(input("Enter Second number:"))
num3 = int(input("Enter third number:"))

# Calculating sum and average
sum_numbers = num1 + num2 + num3
average = sum_numbers / 3
round_avg= round(average,2)

# Displaying the result
print("Sum:", sum_numbers)
print("Average :", round_avg)
# Out:
# Enter First number:8
# Enter Second number:7
# Enter third number:1
# Sum: 16
# Average : 5.33

# %%
## H6: Create a simple calculator that performs basic arithmetic operations (addition, subtraction, multiplication, division) based on user input.
def add(n1, n2):
    return n1 + n2

def sub(n1, n2):
    return n1 - n2

def mul(n1, n2):
    return n1 * n2

def div(n1, n2):
    return n1 / n2

print("Please select operation -\n"
      "1. Add\n"
      "2. Subtract\n"
      "3. Multiply\n"
      "4. Divide\n")

sel = int(input("Select operation (1-4): "))

n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))

if sel == 1:
    print(n1, "+", n2, "=", add(n1, n2))
elif sel == 2:
    print(n1, "-", n2, "=", sub(n1, n2))
elif sel == 3:
    print(n1, "*", n2, "=", mul(n1, n2))
elif sel == 4:
    print(n1, "/", n2, "=", div(n1, n2))
else:
    print("Invalid input")
# Out:
# Please select operation -
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
#
# Select operation (1-4): 1
# Enter first number: 23
# Enter second number: 12
# 23 + 12 = 35

# %%
## H7: Write a program that asks the user to enter a single character and determines whether it is a vowel or a consonant.
# Python3 program to check if a given character is vowel or consonant.

# Function to check whether a character  is vowel or not
x= input("Enter a character:")
def vowelOrConsonant(x):

    if (x == 'a' or x == 'e' or
        x == 'i' or x == 'o' or x == 'u'):
        print("Vowel")
    else:
        print("Consonant")

# Driver code
vowelOrConsonant('c')
vowelOrConsonant('e')
# Out:
# Enter a character:s
# Consonant
# Vowel

# %%
## H8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.
c = int(input("Enter temperature in celsius: "))

# Converting the temperature to Fahrenheit using the formula
f = (c * 1.8) + 32


print("Temperature in Fahrenheit:", f)
# Out:
# Enter temperature in celsius: 45
# Temperature in Fahrenheit: 113.0

# %%
## H8: Create a program that converts temperatures between Fahrenheit and Celsius based on user input.
f=float(input("Enter temperature in Fahrenheit:"))

#converting the temperature to celsius using the formula
c=(f-32)*(0.555)
print("temperature in celsius:", c)
# Out:
# Enter temperature in Fahrenheit:38.5
# temperature in celsius: 3.6075000000000004

# %%
## H9: Write a program that asks the user to enter three numbers and determines which one is the largest.
a= float(input("Enter the value of a:"))
b=float(input("Enter the value of b:"))
c=float(input("Enter the value of c:"))
if(a>b and a>c):
  print("the largest value is a:",a)
elif (b>a and b>c):
  print("the largest value is b:",b)
elif(c>a and c>b):
  print("the largest value is c: ", c)
else:
  print("all values are equal.")
# Out:
# Enter the value of a:12
# Enter the value of b:34
# Enter the value of c:21
# the largest value is b: 34.0

# %%
# H10: Write a program that prompts the user to input a number N and prints all even numbers between 1 and N using a for loop.
n= int(input("Enter an integer:"))
for i in range(2, n, 2):
  print("all the even numbers between 1 to n are:", i)
# Out:
# Enter an integer:10
# all the even numbers between 1 to n are: 2
# all the even numbers between 1 to n are: 4
# all the even numbers between 1 to n are: 6
# all the even numbers between 1 to n are: 8

# %%
# H11: Write a program that prompts the user to input a number N and calculates the sum of all numbers from 1 to N that are divisible by 3 or 5.
n= int(input("Enter an integer:"))
sum=0
for i in range(1, n+1):
  if (i%3==0 or i%5==0):
    sum=sum+i
print("all the even numbers between 1 to n are:", sum)
# Out:
# Enter an integer:10
# all the even numbers between 1 to n are: 33

# %%
# H12: Write a program that prompts the user to input a number n and prints the multiplication table of n (1 to 10) using a for loop
# Multiplication table (from 1 to 10) in Python

num = int(input("Enter a number:"))

# To take input from the user
# num = int(input("Display multiplication table of? "))

# Iterate 10 times from i = 1 to 10
for i in range(1, num+1):
   print(num, 'x', i, '=', num*i)
# Out:
# Enter a number:10
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100
